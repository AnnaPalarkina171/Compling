# %% [markdown]
# # Домашнее задание № 1

# %% [markdown]
# ## 1. Задание на удаление тегов (2 балла)

# %% [markdown]
# Часто в данных, с которыми нам нужно работать помимо текста присутствует ещё какая-то лишняя информация: тэги, ссылки, код, разметка. Она, конечно, не всегда лишняя, но обычно от неё лучше избавиться.

# %% [markdown]
# Возьмем в качестве примера статью с Хабрахабра. Она скачана автоматически и в там остались некоторые тэги.

# %%
text = '''
Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично!<br><br><img src="http://img172.imageshack.us/img172/8434/18274658kc4.png" alt="Сумасшедшее яйцо"><br><br><blockquote><h3>Что это такое?</h3><br>
Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.<br>
Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).<br><br><img src="https://habrastorage.org/getpro/habr/post_images/7c7/298/33c/7c729833cd942cc493e68833e3e0f12d.jpg" alt="Тепловое отслеживание популярности"><br></blockquote><br><br><a name="habracut"></a><br><br><blockquote><h3>Для кого это?</h3><br>
Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0b0/0a0/b16/0b00a0b16b1eda28e35f39487dcd2545.jpg" alt="Отслеживание ссылок"></blockquote><br><blockquote><img src="https://habrastorage.org/getpro/habr/post_images/0b5/433/892/0b54338921665ffb5a90930147296f5b.jpg" alt="Список по популярности"><br><br>
Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса). Зачем это?</h3><br>
С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет <a href="http://ttp://www.crazyegg.com" title="Сумасшедшие яйца">Сумасшедшее яйцо</a>.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/38c/af8/e75/38caf8e753782a01dc6419d3902edd57.jpg" alt="Добавление проекта"></blockquote><br><blockquote>Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0dd/3fb/b34/0dd3fbb34709e77f3fbcd6523c7eac77.jpg" alt="еще полезности"></blockquote><br><blockquote><h3>Как это работает?</h3><br>
Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/a90/e4e/e67/a90e4ee6760978463e6306a2f5982e24.jpg" alt="управление популярностью"></blockquote><br><blockquote><h3>Сколько это стоит?</h3><br>
Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации.</blockquote><br><blockquote>1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.<br><br>
2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции.<br><br>
3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.<br><br>
4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются.<br><br>
5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/f73/fb2/62d/f73fb262da4618a8dde67690cfd191ea.jpg" alt="Отслеживание статистики"></blockquote><br><blockquote><h3>Есть и аналоги</h3><br>
Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.</blockquote><br><blockquote> 1. <a href="https://www.google.com/analytics/home/?hl=en" title="Шикарный сбор и анализ статистики">Google Analytics</a> — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для этого блога.<br><br>
2. <a href="http://www.mapsurface.com/" title="Сервис для отслеживания популярности блоков на сайте">MapSurface</a> — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов. К сожалению он сейчас находится в статусе закрытой беты.</blockquote><br><blockquote><h3>Вывод</h3><br>
Использовать можно, и нужно. Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги. Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию. В общем и целом — <a href="http://ttp://www.crazyegg.com">полезная вещь</a> для каждого владельца сайтов, а для юзабилиста вообще практически обязательна. К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.<br><br><img src="http://img241.imageshack.us/img241/2346/confettitnml5.jpg" alt="Интересная идея визуализации популярности - конфети"></blockquote><br><br>
Автор: <a href="http://www.birzool.com/" title="Я пишу о юзабилити веб интерфейсов">Ярослав Бирзул</a> (DezmASter).<br>
Источник: <a href="http://www.birzool.com/crazyegg/" title="Сумасшедшие яйца, первоисточник">Блог о юзабилити веб интерфейсов</a>.<br><br>
PS: Всех с прошедшим Новым годом! От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах. Удачно вам провести время.
'''

# %%
import re

def remove_tags(text):
  text = re.sub(f"(<.*?>)", " ", text)
  text = re.sub(f"\n", "", text)
  text = re.sub(" +", " ", text)

  return text

text = remove_tags(text)
text
# Out:
# 'Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg . Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично! Что это такое? Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов. Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые). Для кого это? Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями. Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса). Зачем это? С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет Сумасшедшее яйцо . Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей. Как это работает? Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg , поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая. Сколько это стоит? Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации. 1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте. 2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции. 3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора. 4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются. 5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц. Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для э ...

# %% [markdown]
# С помощью регулярных выражение очистите текст от тэгов (мета информацию внутри тэгов тоже удалите). В получившемся тексте точки не должны слипаться с началом следующего предложений, также не должно быть лишних пробелов.

# %% [markdown]
# ## 2. Задание на выбор слов после "не " (1 балл)
#
# Вытащите из очищенного текста все слова, которые идут после частицы "не" (случаи, когда "не" - часть предыдущего слова, не должны извлекаться), **кроме слов, начинающихся на гласную букву**. Сама часть "не " не должна извлекаться.

# %%
re.findall('\sне\s([БВГДЖЗЙКЛМНПРСТФХЦЧШЩбвгдзжйклмнпрстфхцчшщ].*?)[.),]*?\s', text)
# Out:
# ['знаю',
#  'поленился',
#  'бесплатен',
#  'сайтов',
#  'нужно',
#  'лишним',
#  'нужно',
#  'потеряет',
#  'бесплатен',
#  'поленился']

# %% [markdown]
# ## 3. Задание на выбор глаголов (1 балл)
#
# Попробуйте вытащить из очищенного текста как можно больше глаголов (минимум 40 с повоторениями), не перечисляя их в паттерне полностью. Можете токенизировать текст и использовать re.match, а можете использовать re.findall с \\b в начале и конце паттерна, чтобы не матчить части слов.
#
# В результате не должно быть не глаголов. Также постарайтесь сделать паттерн максимально коротким.

# %%
for i,x in enumerate(re.findall(f"\\b([а-яА-ЯёЁ]*?(ить|ать|ешь|аю|ете|ются|етесь|ает|ается|лся|лась|лись|ают|ает))\\b", text)):
  print(i+1,' ', x[0])
# Out:
# 1   знаю
# 2   работает
# 3   Запоминается
# 4   отслеживать
# 5   выводить
# 6   совмещает
# 7   планировался
# 8   дает
# 9   знать
# 10   популяризировался
# 11   предполагает
# 12   написать
# 13   поленился
# 14   заплатить
# 15   потестировать
# 16   отслеживать
# 17   хватает
# 18   тасовать
# 19   спорить
# 20   расположить
# 21   располагать
# 22   вычислить
# 23   приносить
# 24   работает
# 25   работает
# 26   Включает
# 27   отследить
# 28   Отличается
# 29   окупаются
# 30   отследить
# 31   поленился
# 32   предлагают
# 33   Использовать
# 34   кусаются
# 35   отбиваются
# 36   Использовать
# 37   помогает
# 38   повысить
# 39   поиздержались
# 40   желаю
# 41   желаете

# %% [markdown]
# ## 4. Pymorphy vs Mystem (2 балла)

# %% [markdown]
# Лемматизируйте очищенный текст с помощью mystem и pymorphy. Сравните результаты: есть ли разница, что лучше.

# %% [markdown]
# Для пайморфи используйте токенизацию из mystem, чтобы исключить влияние токенизации на результат.

# %%
# !pip install razdel
# !pip install pymorphy2

from razdel import tokenize
from razdel import sentenize
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')  
nltk.download('punkt')
from string import punctuation
import pymorphy2
import pandas as pd

morph = pymorphy2.MorphAnalyzer()
russian_stopwords = stopwords.words('russian')
punctuation = punctuation + '„“—'
from tqdm import tqdm
# Out:
# Requirement already satisfied: razdel in c:\users\annet\anaconda3\lib\site-packages (0.5.0)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\annet\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pymorphy2 in c:\users\annet\anaconda3\lib\site-packages (0.8)
# Requirement already satisfied: docopt>=0.6 in c:\users\annet\anaconda3\lib\site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7 in c:\users\annet\anaconda3\lib\site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in c:\users\annet\anaconda3\lib\site-packages (from pymorphy2) (2.4.393442.3710985)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\annet\anaconda3\python.exe -m pip install --upgrade pip' command.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\annet\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\annet\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip install pymystem3
from pymystem3 import Mystem
import os, json
mystem = Mystem()
# Out:
# Requirement already satisfied: pymystem3 in c:\users\annet\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: requests in c:\users\annet\anaconda3\lib\site-packages (from pymystem3) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\annet\anaconda3\lib\site-packages (from requests->pymystem3) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\annet\anaconda3\lib\site-packages (from requests->pymystem3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\annet\anaconda3\lib\site-packages (from requests->pymystem3) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\annet\anaconda3\lib\site-packages (from requests->pymystem3) (1.25.9)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\annet\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()

# %%
words_analized = mystem.analyze(text)
tokens = []
for word in words_analized:
    if word['text'] != ' ':
        tokens.append(word['text'])
tokens
# Out:
# ['Сегодняшняя',
#  'заметка',
#  'будет',
#  'о',
#  'сервисе',
#  'отслеживания',
#  'активности',
#  'пользователя',
#  ' — ',
#  'CrazyEgg',
#  '. ',
#  'Я',
#  'не',
#  'знаю',
#  'кому',
#  'обязан',
#  'сервис',
#  'таким',
#  'говорящим',
#  'именем',
#  ', ',
#  'но',
#  'оно',
#  'работает',
#  ', ',
#  'и',
#  'хорошо',
#  '. ',
#  'Запоминается',
#  '? ',
#  'Отлично',
#  '! ',
#  'Что',
#  'это',
#  'такое',
#  '? ',
#  'Как',
#  'уже',
#  'сказано',
#  'выше',
#  'это',
#  'сервис',
#  'для',
#  'отслеживания',
#  'перемещения',
#  'пользователей',
#  'по',
#  'сайту',
#  ' — ',
#  'кто',
#  'куда',
#  'кликнул',
#  ', ',
#  'какие',
#  'ссылки',
#  'наиболее',
#  'популярные',
#  'и',
#  'тому',
#  'подобная',
#  ', ',
#  'разнородная',
#  'информация',
#  'для',
#  'юзабилистов',
#  '. ',
#  'Сервис',
#  'позволяет',
#  'отслеживать',
#  'активность',
#  'определенных',
#  'пользователей',
#  ', ',
#  'и',
#  'выводить',
#  'эти',
#  'данные',
#  'в',
#  'различных',
#  'формах',
#  ': «',
#  'инфракрасная',
#  '» — ',
#  'где',
#  'чем',
#  'активнее',
#  'область',
#  ', ',
#  'тем',
#  'она',
#  ' «',
#  'теплее',
#  '», ',
#  'салюты',
#  ' (',
#  'чем',
#  'активнее',
#  'область',
#  ', ',
#  'тем',
#  'больше',
#  'конфети',
#  '), ',
#  'простой',
#  'список',
#  'с',
#  'сортировкой',
#  'по',
#  'активности',
#  ', ',
#  'колбы',
#  ' (',
#  'чем',
#  'заполненнее',
#  'колба',
#  ', ',
#  'тем',
#  'активнее',
#  'область',
#  '), ',
#  'облака',
#  ' (',
#  'на',
#  'мой',
#  'взгляд',
#  'наиболее',
#  'удобный',
#  'вариант',
#  ' — ',
#  'совмещает',
#  'в',
#  'себе',
#  'все',
#  'остальные',
#  'вместе',
#  'взятые',
#  ')',
#  '. ',
#  'Для',
#  'кого',
#  'это',
#  '? ',
#  'Разумеется',
#  'сервис',
#  'изначально',
#  'планировался',
#  'как',
#  'первый',
#  'помощник',
#  'для',
#  'юзабилистов',
#  ', ',
#  'но',
#  'пользоваться',
#  'им',
#  'может',
#  'каждый',
#  ', ',
#  'у',
#  'кого',
#  'есть',
#  'деньги',
#  ' — ',
#  'интуитивный',
#  'интерфейс',
#  ', ',
#  'и',
#  'хороший',
#  'дизайн',
#  'дает',
#  'о',
#  'себе',
#  'знать',
#  ' — ',
#  'сервис',
#  'массово',
#  'популяризировался',
#  'пол',
#  'года',
#  '-',
#  'год',
#  'назад',
#  '. ',
#  'Относительно',
#  'недорогой',
#  ', ',
#  'но',
#  'уж',
#  'точно',
#  'не',
#  'из',
#  'дешевых',
#  ' — ',
#  'сервис',
#  'предполагает',
#  'собой',
#  '4',
#  'платных',
#  'линии',
#  'и',
#  'одну',
#  'бесплатную',
#  '. ',
#  'Дабы',
#  'написать',
#  'этот',
#  'обзор',
#  'я',
#  'не',
#  'поленился',
#  'заплатить',
#  '19',
#  'долларов',
#  ' (',
#  'в',
#  'месяц',
#  ') ',
#  'выбрав',
#  'средний',
#  'вариант',
#  ' — ',
#  'для',
#  'нескольких',
#  'проектов',
#  'с',
#  'включенными',
#  'дополнительными',
#  'функциями',
#  '. ',
#  'Да',
#  '-',
#  'да',
#  ', ',
#  'сервис',
#  'не',
#  'бесплатен',
#  '. ',
#  'Точнее',
#  'бесплатная',
#  'возможность',
#  'потестировать',
#  'есть',
#  ', ',
#  'но',
#  'она',
#  'немного',
#  'обрезана',
#  ' (',
#  'можно',
#  'отслеживать',
#  'только',
#  '5000',
#  'посетителей',
#  'и',
#  'всего',
#  '4',
#  'страницы',
#  'на',
#  'сайте',
#  ' (',
#  'внимание',
#  ' — ',
#  '4',
#  'страницы',
#  ', ',
#  'а',
#  'не',
#  'сайтов',
#  '), ',
#  'т',
#  '.',
#  'е',
#  '.',
#  'вполне',
#  'хватает',
#  'для',
#  'того',
#  ', ',
#  'чтобы',
#  'понять',
#  'полезность',
#  'сервиса',
#  ')',
#  '. ',
#  'Зачем',
#  'это',
#  '? ',
#  'С',
#  'помощью',
#  'этого',
#  'сервиса',
#  'можно',
#  'тасовать',
#  'блоки',
#  'на',
#  'сайте',
#  ', ',
#  'которые',
#  'полезны',
#  'пользователям',
#  'больше',
#  'всего',
#  '. ',
#  'Больше',
#  'не',
#  'нужно',
#  'спорить',
#  'создателям',
#  ' — ',
#  'какой',
#  'блок',
#  'где',
#  'расположить',
#  '. ',
#  'В',
#  'этом',
#  'им',
#  'поможет',
#  'Сумасшедшее',
#  'яйцо',
#  '. ',
#  'Также',
#  'этот',
#  'сервис',
#  'поможет',
#  'вам',
#  'понять',
#  ' — ',
#  'в',
#  'какой',
#  'зоне',
#  'сайта',
#  'лучше',
#  'всего',
#  'располагать',
#  'рекламу',
#  ', ',
#  'когда',
#  'в',
#  'вашем',
#  'сервисе',
#  'речь',
#  'зайдет',
#  'о',
#  'монетизации',
#  '. ',
#  'Ведь',
#  'альтруизм',
#  'это',
#  'хорошо',
#  ', ',
#  'а',
#  'деньги',
#  'на',
#  'содержание',
#  'сервиса',
#  'нужны',
#  ', ',
#  'и',
#  'не',
#  'лишним',
#  'будет',
#  'вычислить',
#  'зоны',
#  'где',
#  'реклама',
#  'будет',
#  'приносить',
#  'наибольшую',
#  'отдачу',
#  ', ',
#  'и',
#  'наименьшее',
#  'раздражение',
#  'у',
#  'пользователей',
#  '. ',
#  'Как',
#  'это',
#  'работает',
#  '? ',
#  'Никаких',
#  'километровых',
#  'скриптов',
#  'вставлять',
#  'не',
#  'нужно',
#  ', ',
#  'достаточно',
#  'вставиь',
#  '2',
#  'строчки',
#  'яваскрипта',
#  ', ',
#  'и',
#  'сервис',
#  'начнет',
#  'отслеживание',
#  '. ',
#  'Насколько',
#  'я',
#  'понял',
#  ' — ',
#  'исполнительный',
#  'скрипт',
#  'работает',
#  'на',
#  'сервере',
#  'CrazyEgg',
#  ' , ',
#  'поэтому',
#  'ваш',
#  'сайт',
#  'от',
#  'этого',
#  'в',
#  'производительности',
#  'не',
#  'потеряет',
#  'ни',
#  'секунды',
#  ', ',
#  'а',
#  'полезность',
#  'довольно',
#  'таки',
#  'большая',
#  '. ',
#  'Сколько',
#  'это',
#  'стоит',
#  '? ',
#  'Как',
#  'я',
#  'уже',
#  'упоминал',
#  ' — ',
#  'сервис',
#  'далеко',
#  'не',
#  'бесплатен',
#  ', ',
#  'хоть',
#  'и',
#  'имеет',
#  'тестовую',
#  '-',
#  'бесплатную',
#  'версию',
#  '. ',
#  'Расскажу',
#  'подробнее',
#  'о',
#  'тарификации',
#  '. ',
#  '1',
#  '. ',
#  'Бесплатная',
#  'тестовая',
#  'версия',
#  '. ',
#  'Включает',
#  'в',
#  'себя',
#  'возможность',
#  'отслеживания',
#  '5',
#  '000',
#  'посещений',
#  ', ',
#  '4',
#  'страницы',
#  'на',
#  'сайте',
#  '. ',
#  '2',
#  '. ',
#  'Базовая',
#  'версия',
#  '. ',
#  'В',
#  'этой',
#  'версии',
#  'можно',
#  'отследить',
#  '10',
#  '000',
#  'посещений',
#  ', ',
#  'и',
#  '10',
#  'страниц',
#  ', ',
#  'что',
#  'вполне',
#  'достаточно',
#  'для',
#  'среднего',
#  'корпоративного',
#  'сайта',
#  '. ',
#  'Стоит',
#  'базовый',
#  'комплект',
#  ' — ',
#  '9',
#  'долларов',
#  'в',
#  'месяц',
#  '. ',
#  'В',
#  'этот',
#  'комплект',
#  'включены',
#  'все',
#  'дополнительные',
#  'функции',
#  '. ',
#  '3',
#  '. ',
#  'Версия',
#  ' «',
#  'Стандарт',
#  '»',
#  '. ',
#  'В',
#  'неё',
#  'входит',
#  'возможность',
#  'отслеживания',
#  '25',
#  '000',
#  'посещений',
#  'на',
#  '20',
#  'страницах',
#  '. ',
#  'Вполне',
#  'подходит',
#  'для',
#  'тестирования',
#  'нового',
#  'стартапа',
#  '. ',
#  'Стоит',
#  'она',
#  '19',
#  'долларов',
#  'в',
#  'месяц',
#  ', ',
#  'именно',
#  'её',
#  'я',
#  'купил',
#  'для',
#  'тестирования',
#  'сервиса',
#  ', ',
#  'и',
#  'написания',
#  'этого',
#  'обзора',
#  '. ',
#  '4',
#  '. ',
#  'Версия',
#  ' «',
#  'Плюс',
#  '»',
#  '. ',
#  'Отличается',
#  'от',
#  'предыдущей',
#  'возможностью',
#  'отслеживания',
#  '100',
#  '000',
#  'посещений',
#  ', ',
#  '50',
#  'страниц',
#  '. ',
#  'Очень',
#  'хороший',
#  'тариф',
#  'для',
#  'крупных',
#  'сервисов',
#  '. ',
#  'Стоит',
#  '49',
#  'долларов',
#  'в',
#  'месяц',
#  '. ',
#  'Довольно',
#  'большие',
#  'деньги',
#  'за',
#  'сервис',
#  ', ',
#  'но',
#  'они',
#  'обычно',
#  'с',
#  'лихвой',
#  'окупаются',
#  '. ',
#  '5',
#  '. ',
#  'Версия',
#  ' «',
#  'Про',
#  '»',
#  '. ',
#  'Стоит',
#  'почти',
#  '100',
#  'долларов',
#  ', ',
#  'имеет',
#  'возможность',
#  'отследить',
#  '250',
#  '000',
#  'посещений',
#  'на',
#  'ста',
#  'страницах',
#  '. ',
#  'Тариф',
#  'подходит',
#  'для',
#  'монстров',
#  'с',
#  'большой',
#  'посещаемостью',
#  'и',
#  'большим',
#  'количеством',
#  'страниц',
#  '. ',
#  'Есть',
#  'и',
#  'аналоги',
#  'Я',
#  'не',
#  'поленился',
#  ', ',
#  'и',
#  'собрал',
#  'еще',
#  'пару',
#  'ссылок',
#  'с',
#  'аналогами',
#  ', ',
#  'которые',
#  'предлагают',
#  'такие',
#  'же',
#  'услуги',
#  ', ',
#  'но',
#  'немного',
#  'дешевле',
#  '. ',
#  '1',
#  '. ',
#  'Google',
#  'Analytics',
#  ' — ',
#  'бесплатный',
#  'сервис',
#  'для',
#  'сбора',
#  'и',
#  'анализа',
#  'статистики',
#  ', ',
#  'вывод',
#  'статистики',
#  'в',
#  'наиболее',
#  'наглядной',
#  'форме',
#  ', ',
#  'и',
#  'без',
#  'разнообразных',
#  'рейтингов',
#  ', ',
#  'счетчиков',
#  '. ',
#  'Очень',
#  'подробная',
#  'и',
#  'полезная',
#  'вещь',
#  '. ',
#  'Рекомендую',
#  ', ',
#  'т',
#  '.',
#  'к',
#  '.',
#  'сам',
#  'пользуюсь',
#  'им',
#  'для',
#  'этого',
#  'блога',
#  '. ',
#  '2',
#  '. ',
#  'MapSurface',
#  ' — ',
#  'сам',
#  'еще',
#  'не',
#  'использовал',
#  ' (',
#  'т',
#  '.',
#  'к',
#  '.',
#  'предпочел',
#  'CrazyEgg',
#  '), ',
#  'но',
#  'врядли',
#  'будучи',
#  'плохим',
#  'сервис',
#  'собрал',
#  'бы',
#  'множество',
#  'положительных',
#  'отзывов',
#  '. ',
#  'К',
#  'сожалению',
#  'он',
#  'сейчас',
#  'находится',
#  'в',
#  'статусе',
#  'закрытой',
#  'беты',
#  '. ',
#  'Вывод',
#  'Использовать',
#  'можно',
#  ', ',
#  'и',
#  'нужно',
#  '. ',
#  'Вот',
#  'только',
#  'тарифы',
#  'довольно',
#  'больно',
#  'кусаются',
#  ', ',
#  'но',
#  'обычно',
#  'эти',
#  'деньги',
#  'потом',
#  'с',
#  'лихвой',
#  'отбиваются',
#  'на',
#  'повышении',
#  'конвертации',
#  'посетителей',
#  'в',
#  'деньги',
#  '. ',
#  'Использовать',
#  'сервис',
#  'нужно',
#  'для',
#  'тестирования',
#  'рекламных',
#  'мест',
#  'и',
#  'удобства',
#  'отдельных',
#  'страниц',
#  ', ',
#  'что',
#  'помогает',
#  'опять',
#  'же',
#  'повысить',
#  'конвертацию',
#  '. ',
#  'В',
#  'общем',
#  'и',
#  'целом',
#  ' — ',
#  'полезная',
#  'вещь',
#  'для',
#  'каждого',
#  'владельца',
#  'сайтов',
#  ', ',
#  'а',
#  'для',
#  'юзабилиста',
#  'вообще',
#  'практически',
#  'обязательна',
#  '. ',
#  'К',
#  'счастью',
#  'для',
#  'людей',
#  ', ',
#  'которые',
#  'поиздержались',
#  'деньгами',
#  'в',
#  'этом',
#  'месяце',
#  ' — ',
#  'есть',
#  'полезные',
#  'аналоги',
#  '. ',
#  'Автор',
#  ': ',
#  'Ярослав',
#  'Бирзул',
#  ' (',
#  'DezmASter',
#  ')',
#  '. ',
#  'Источник',
#  ': ',
#  'Блог',
#  'о',
#  'юзабилити',
#  'веб',
#  'интерфейсов',
#  '. ',
#  'PS',
#  ': ',
#  'Всех',
#  'с',
#  'прошедшим',
#  'Новым',
#  'годом',
#  '! ',
#  'От',
#  'всей',
#  'души',
#  'желаю',
#  'вам',
#  'всего',
#  'самого',
#  '-',
#  'самого',
#  'лучшего',
#  ', ',
#  'чего',
#  'вы',
#  'желаете',
#  'только',
#  'в',
#  'самых',
#  'сокровенных',
#  'мечтах',
#  '. ',
#  'Удачно',
#  'вам',
#  'провести',
#  'время',
#  '.',
#  '\n']

# %%
mystem_lemmas = [x for x in mystem.lemmatize(text) if x != ' ']
mystem_lemmas
# Out:
# ['сегодняшний',
#  'заметка',
#  'быть',
#  'о',
#  'сервис',
#  'отслеживание',
#  'активность',
#  'пользователь',
#  ' — ',
#  'CrazyEgg',
#  '. ',
#  'я',
#  'не',
#  'знать',
#  'кто',
#  'обязанный',
#  'сервис',
#  'такой',
#  'говорящий',
#  'имя',
#  ', ',
#  'но',
#  'оно',
#  'работать',
#  ', ',
#  'и',
#  'хорошо',
#  '. ',
#  'запоминаться',
#  '? ',
#  'отлично',
#  '! ',
#  'что',
#  'это',
#  'такой',
#  '? ',
#  'как',
#  'уже',
#  'сказать',
#  'выше',
#  'это',
#  'сервис',
#  'для',
#  'отслеживание',
#  'перемещение',
#  'пользователь',
#  'по',
#  'сайт',
#  ' — ',
#  'кто',
#  'куда',
#  'кликнуть',
#  ', ',
#  'какой',
#  'ссылка',
#  'наиболее',
#  'популярный',
#  'и',
#  'тот',
#  'подобный',
#  ', ',
#  'разнородный',
#  'информация',
#  'для',
#  'юзабилист',
#  '. ',
#  'сервис',
#  'позволять',
#  'отслеживать',
#  'активность',
#  'определенный',
#  'пользователь',
#  ', ',
#  'и',
#  'выводить',
#  'этот',
#  'данные',
#  'в',
#  'различный',
#  'форма',
#  ': «',
#  'инфракрасный',
#  '» — ',
#  'где',
#  'чем',
#  'активно',
#  'область',
#  ', ',
#  'тем',
#  'она',
#  ' «',
#  'тепло',
#  '», ',
#  'салют',
#  ' (',
#  'чем',
#  'активно',
#  'область',
#  ', ',
#  'тем',
#  'много',
#  'конфеть',
#  '), ',
#  'простой',
#  'список',
#  'с',
#  'сортировка',
#  'по',
#  'активность',
#  ', ',
#  'колба',
#  ' (',
#  'чем',
#  'заполненный',
#  'колба',
#  ', ',
#  'тем',
#  'активно',
#  'область',
#  '), ',
#  'облако',
#  ' (',
#  'на',
#  'мой',
#  'взгляд',
#  'наиболее',
#  'удобный',
#  'вариант',
#  ' — ',
#  'совмещать',
#  'в',
#  'себя',
#  'весь',
#  'остальной',
#  'вместе',
#  'взять',
#  ')',
#  '. ',
#  'для',
#  'кто',
#  'это',
#  '? ',
#  'разумеется',
#  'сервис',
#  'изначально',
#  'планироваться',
#  'как',
#  'первый',
#  'помощник',
#  'для',
#  'юзабилист',
#  ', ',
#  'но',
#  'пользоваться',
#  'они',
#  'может',
#  'каждый',
#  ', ',
#  'у',
#  'кто',
#  'быть',
#  'деньги',
#  ' — ',
#  'интуитивный',
#  'интерфейс',
#  ', ',
#  'и',
#  'хороший',
#  'дизайн',
#  'давать',
#  'о',
#  'себя',
#  'знать',
#  ' — ',
#  'сервис',
#  'массово',
#  'популяризироваться',
#  'пол',
#  'год',
#  '-',
#  'год',
#  'назад',
#  '. ',
#  'относительно',
#  'недорогой',
#  ', ',
#  'но',
#  'уж',
#  'точно',
#  'не',
#  'из',
#  'дешевый',
#  ' — ',
#  'сервис',
#  'предполагать',
#  'себя',
#  '4',
#  'платный',
#  'линия',
#  'и',
#  'один',
#  'бесплатный',
#  '. ',
#  'дабы',
#  'написать',
#  'этот',
#  'обзор',
#  'я',
#  'не',
#  'полениться',
#  'заплатить',
#  '19',
#  'доллар',
#  ' (',
#  'в',
#  'месяц',
#  ') ',
#  'выбирать',
#  'средний',
#  'вариант',
#  ' — ',
#  'для',
#  'несколько',
#  'проект',
#  'с',
#  'включать',
#  'дополнительный',
#  'функция',
#  '. ',
#  'да',
#  '-',
#  'да',
#  ', ',
#  'сервис',
#  'не',
#  'бесплатный',
#  '. ',
#  'точно',
#  'бесплатный',
#  'возможность',
#  'потестировать',
#  'есть',
#  ', ',
#  'но',
#  'она',
#  'немного',
#  'обрезать',
#  ' (',
#  'можно',
#  'отслеживать',
#  'только',
#  '5000',
#  'посетитель',
#  'и',
#  'все',
#  '4',
#  'страница',
#  'на',
#  'сайт',
#  ' (',
#  'внимание',
#  ' — ',
#  '4',
#  'страница',
#  ', ',
#  'а',
#  'не',
#  'сайт',
#  '), ',
#  'т',
#  '.',
#  'е',
#  '.',
#  'вполне',
#  'хватать',
#  'для',
#  'то',
#  ', ',
#  'чтобы',
#  'понимать',
#  'полезность',
#  'сервис',
#  ')',
#  '. ',
#  'зачем',
#  'это',
#  '? ',
#  'с',
#  'помощь',
#  'этот',
#  'сервис',
#  'можно',
#  'тасовать',
#  'блок',
#  'на',
#  'сайт',
#  ', ',
#  'который',
#  'полезный',
#  'пользователь',
#  'много',
#  'все',
#  '. ',
#  'больше',
#  'не',
#  'нужно',
#  'спорить',
#  'создатель',
#  ' — ',
#  'какой',
#  'блок',
#  'где',
#  'располагать',
#  '. ',
#  'в',
#  'это',
#  'он',
#  'помогать',
#  'сумасшедший',
#  'яйцо',
#  '. ',
#  'также',
#  'этот',
#  'сервис',
#  'помогать',
#  'вы',
#  'понимать',
#  ' — ',
#  'в',
#  'какой',
#  'зона',
#  'сайт',
#  'хорошо',
#  'все',
#  'располагать',
#  'реклама',
#  ', ',
#  'когда',
#  'в',
#  'ваш',
#  'сервис',
#  'речь',
#  'зайти',
#  'о',
#  'монетизация',
#  '. ',
#  'ведь',
#  'альтруизм',
#  'это',
#  'хорошо',
#  ', ',
#  'а',
#  'деньги',
#  'на',
#  'содержание',
#  'сервис',
#  'нужный',
#  ', ',
#  'и',
#  'не',
#  'лишний',
#  'быть',
#  'вычислять',
#  'зона',
#  'где',
#  'реклама',
#  'быть',
#  'приносить',
#  'большой',
#  'отдача',
#  ', ',
#  'и',
#  'маленький',
#  'раздражение',
#  'у',
#  'пользователь',
#  '. ',
#  'как',
#  'это',
#  'работать',
#  '? ',
#  'никакой',
#  'километровый',
#  'скрипт',
#  'вставлять',
#  'не',
#  'нужно',
#  ', ',
#  'достаточно',
#  'вставиь',
#  '2',
#  'строчка',
#  'яваскрипт',
#  ', ',
#  'и',
#  'сервис',
#  'начинать',
#  'отслеживание',
#  '. ',
#  'насколько',
#  'я',
#  'понимать',
#  ' — ',
#  'исполнительный',
#  'скрипт',
#  'работать',
#  'на',
#  'сервер',
#  'CrazyEgg',
#  ' , ',
#  'поэтому',
#  'ваш',
#  'сайт',
#  'от',
#  'это',
#  'в',
#  'производительность',
#  'не',
#  'потерять',
#  'ни',
#  'секунда',
#  ', ',
#  'а',
#  'полезность',
#  'довольно',
#  'таки',
#  'большой',
#  '. ',
#  'сколько',
#  'это',
#  'стоять',
#  '? ',
#  'как',
#  'я',
#  'уже',
#  'упоминать',
#  ' — ',
#  'сервис',
#  'далеко',
#  'не',
#  'бесплатный',
#  ', ',
#  'хоть',
#  'и',
#  'иметь',
#  'тестовый',
#  '-',
#  'бесплатный',
#  'версия',
#  '. ',
#  'рассказывать',
#  'подробно',
#  'о',
#  'тарификация',
#  '. ',
#  '1',
#  '. ',
#  'бесплатный',
#  'тестовый',
#  'версия',
#  '. ',
#  'включать',
#  'в',
#  'себя',
#  'возможность',
#  'отслеживание',
#  '5',
#  '000',
#  'посещение',
#  ', ',
#  '4',
#  'страница',
#  'на',
#  'сайт',
#  '. ',
#  '2',
#  '. ',
#  'базовый',
#  'версия',
#  '. ',
#  'в',
#  'этот',
#  'версия',
#  'можно',
#  'отслеживать',
#  '10',
#  '000',
#  'посещение',
#  ', ',
#  'и',
#  '10',
#  'страница',
#  ', ',
#  'что',
#  'вполне',
#  'достаточно',
#  'для',
#  'средний',
#  'корпоративный',
#  'сайт',
#  '. ',
#  'стоять',
#  'базовый',
#  'комплект',
#  ' — ',
#  '9',
#  'доллар',
#  'в',
#  'месяц',
#  '. ',
#  'в',
#  'этот',
#  'комплект',
#  'включать',
#  'весь',
#  'дополнительный',
#  'функция',
#  '. ',
#  '3',
#  '. ',
#  'версия',
#  ' «',
#  'стандарт',
#  '»',
#  '. ',
#  'в',
#  'она',
#  'входить',
#  'возможность',
#  'отслеживание',
#  '25',
#  '000',
#  'посещение',
#  'на',
#  '20',
#  'страница',
#  '. ',
#  'вполне',
#  'подходить',
#  'для',
#  'тестирование',
#  'новый',
#  'стартап',
#  '. ',
#  'стоить',
#  'она',
#  '19',
#  'доллар',
#  'в',
#  'месяц',
#  ', ',
#  'именно',
#  'она',
#  'я',
#  'купить',
#  'для',
#  'тестирование',
#  'сервис',
#  ', ',
#  'и',
#  'написание',
#  'этот',
#  'обзор',
#  '. ',
#  '4',
#  '. ',
#  'версия',
#  ' «',
#  'плюс',
#  '»',
#  '. ',
#  'отличаться',
#  'от',
#  'предыдущий',
#  'возможность',
#  'отслеживание',
#  '100',
#  '000',
#  'посещение',
#  ', ',
#  '50',
#  'страница',
#  '. ',
#  'очень',
#  'хороший',
#  'тариф',
#  'для',
#  'крупный',
#  'сервис',
#  '. ',
#  'стоять',
#  '49',
#  'доллар',
#  'в',
#  'месяц',
#  '. ',
#  'довольно',
#  'большой',
#  'деньги',
#  'за',
#  'сервис',
#  ', ',
#  'но',
#  'они',
#  'обычно',
#  'с',
#  'лихва',
#  'окупаться',
#  '. ',
#  '5',
#  '. ',
#  'версия',
#  ' «',
#  'про',
#  '»',
#  '. ',
#  'стоять',
#  'почти',
#  '100',
#  'доллар',
#  ', ',
#  'иметь',
#  'возможность',
#  'отслеживать',
#  '250',
#  '000',
#  'посещение',
#  'на',
#  'сто',
#  'страница',
#  '. ',
#  'тариф',
#  'подходить',
#  'для',
#  'монстр',
#  'с',
#  'большой',
#  'посещаемость',
#  'и',
#  'большой',
#  'количество',
#  'страница',
#  '. ',
#  'быть',
#  'и',
#  'аналог',
#  'я',
#  'не',
#  'полениться',
#  ', ',
#  'и',
#  'собирать',
#  'еще',
#  'пара',
#  'ссылка',
#  'с',
#  'аналог',
#  ', ',
#  'который',
#  'предлагать',
#  'такой',
#  'же',
#  'услуга',
#  ', ',
#  'но',
#  'немного',
#  'дешево',
#  '. ',
#  '1',
#  '. ',
#  'Google',
#  'Analytics',
#  ' — ',
#  'бесплатный',
#  'сервис',
#  'для',
#  'сбор',
#  'и',
#  'анализ',
#  'статистика',
#  ', ',
#  'вывод',
#  'статистика',
#  'в',
#  'наиболее',
#  'наглядный',
#  'форма',
#  ', ',
#  'и',
#  'без',
#  'разнообразный',
#  'рейтинг',
#  ', ',
#  'счетчик',
#  '. ',
#  'очень',
#  'подробный',
#  'и',
#  'полезный',
#  'вещь',
#  '. ',
#  'рекомендовать',
#  ', ',
#  'т',
#  '.',
#  'к',
#  '.',
#  'сам',
#  'пользоваться',
#  'он',
#  'для',
#  'этот',
#  'блог',
#  '. ',
#  '2',
#  '. ',
#  'MapSurface',
#  ' — ',
#  'сам',
#  'еще',
#  'не',
#  'использовать',
#  ' (',
#  'т',
#  '.',
#  'к',
#  '.',
#  'предпочитать',
#  'CrazyEgg',
#  '), ',
#  'но',
#  'врядли',
#  'быть',
#  'плохой',
#  'сервис',
#  'собирать',
#  'бы',
#  'множество',
#  'положительный',
#  'отзыв',
#  '. ',
#  'к',
#  'сожаление',
#  'он',
#  'сейчас',
#  'находиться',
#  'в',
#  'статус',
#  'закрытый',
#  'бета',
#  '. ',
#  'вывод',
#  'использовать',
#  'можно',
#  ', ',
#  'и',
#  'нужно',
#  '. ',
#  'вот',
#  'только',
#  'тариф',
#  'довольно',
#  'больно',
#  'кусаться',
#  ', ',
#  'но',
#  'обычно',
#  'этот',
#  'деньги',
#  'потом',
#  'с',
#  'лихва',
#  'отбиваться',
#  'на',
#  'повышение',
#  'конвертация',
#  'посетитель',
#  'в',
#  'деньги',
#  '. ',
#  'использовать',
#  'сервис',
#  'нужный',
#  'для',
#  'тестирование',
#  'рекламный',
#  'место',
#  'и',
#  'удобство',
#  'отдельный',
#  'страница',
#  ', ',
#  'что',
#  'помогать',
#  'опять',
#  'же',
#  'повышать',
#  'конвертация',
#  '. ',
#  'в',
#  'общий',
#  'и',
#  'целое',
#  ' — ',
#  'полезный',
#  'вещь',
#  'для',
#  'каждый',
#  'владелец',
#  'сайт',
#  ', ',
#  'а',
#  'для',
#  'юзабилист',
#  'вообще',
#  'практически',
#  'обязательный',
#  '. ',
#  'к',
#  'счастие',
#  'для',
#  'человек',
#  ', ',
#  'который',
#  'поиздержаться',
#  'деньги',
#  'в',
#  'этот',
#  'месяц',
#  ' — ',
#  'быть',
#  'полезный',
#  'аналог',
#  '. ',
#  'автор',
#  ': ',
#  'ярослав',
#  'бирзула',
#  ' (',
#  'DezmASter',
#  ')',
#  '. ',
#  'источник',
#  ': ',
#  'блог',
#  'о',
#  'юзабилити',
#  'веб',
#  'интерфейс',
#  '. ',
#  'PS',
#  ': ',
#  'весь',
#  'с',
#  'прошедший',
#  'новый',
#  'год',
#  '! ',
#  'от',
#  'весь',
#  'душа',
#  'желать',
#  'вы',
#  'весь',
#  'самый',
#  '-',
#  'самый',
#  'хороший',
#  ', ',
#  'что',
#  'вы',
#  'желать',
#  'только',
#  'в',
#  'самый',
#  'сокровенный',
#  'мечта',
#  '. ',
#  'удачно',
#  'вы',
#  'проводить',
#  'время',
#  '.',
#  '\n']

# %%
pymorphy_lemmas = [morph.parse(str(token))[0].normal_form for token in tokens]
pymorphy_lemmas
# Out:
# ['сегодняшний',
#  'заметка',
#  'быть',
#  'о',
#  'сервис',
#  'отслеживание',
#  'активность',
#  'пользователь',
#  ' — ',
#  'crazyegg',
#  '. ',
#  'я',
#  'не',
#  'знать',
#  'кома',
#  'обязать',
#  'сервис',
#  'такой',
#  'говорящий',
#  'имя',
#  ', ',
#  'но',
#  'оно',
#  'работать',
#  ', ',
#  'и',
#  'хорошо',
#  '. ',
#  'запоминаться',
#  '? ',
#  'отлично',
#  '! ',
#  'что',
#  'это',
#  'такой',
#  '? ',
#  'как',
#  'уже',
#  'сказать',
#  'выше',
#  'это',
#  'сервис',
#  'для',
#  'отслеживание',
#  'перемещение',
#  'пользователь',
#  'по',
#  'сайт',
#  ' — ',
#  'кто',
#  'куда',
#  'кликнуть',
#  ', ',
#  'какой',
#  'ссылка',
#  'наиболее',
#  'популярный',
#  'и',
#  'тот',
#  'подобный',
#  ', ',
#  'разнородный',
#  'информация',
#  'для',
#  'юзабилист',
#  '. ',
#  'сервис',
#  'позволять',
#  'отслеживать',
#  'активность',
#  'определённый',
#  'пользователь',
#  ', ',
#  'и',
#  'выводить',
#  'этот',
#  'дать',
#  'в',
#  'различный',
#  'форма',
#  ': «',
#  'инфракрасный',
#  '» — ',
#  'где',
#  'чем',
#  'активный',
#  'область',
#  ', ',
#  'тем',
#  'она',
#  ' «',
#  'тёплый',
#  '», ',
#  'салют',
#  ' (',
#  'чем',
#  'активный',
#  'область',
#  ', ',
#  'тем',
#  'большой',
#  'конфести',
#  '), ',
#  'простой',
#  'список',
#  'с',
#  'сортировка',
#  'по',
#  'активность',
#  ', ',
#  'колба',
#  ' (',
#  'чем',
#  'залненный',
#  'колба',
#  ', ',
#  'тем',
#  'активный',
#  'область',
#  '), ',
#  'облако',
#  ' (',
#  'на',
#  'мой',
#  'взгляд',
#  'наиболее',
#  'удобный',
#  'вариант',
#  ' — ',
#  'совмещать',
#  'в',
#  'себя',
#  'весь',
#  'остальной',
#  'вместе',
#  'взять',
#  ')',
#  '. ',
#  'для',
#  'кто',
#  'это',
#  '? ',
#  'разумеется',
#  'сервис',
#  'изначально',
#  'планироваться',
#  'как',
#  'один',
#  'помощник',
#  'для',
#  'юзабилист',
#  ', ',
#  'но',
#  'пользоваться',
#  'имя',
#  'мочь',
#  'каждый',
#  ', ',
#  'у',
#  'кто',
#  'есть',
#  'деньга',
#  ' — ',
#  'интуитивный',
#  'интерфейс',
#  ', ',
#  'и',
#  'хороший',
#  'дизайн',
#  'давать',
#  'о',
#  'себя',
#  'знать',
#  ' — ',
#  'сервис',
#  'массово',
#  'популяризироваться',
#  'половина',
#  'год',
#  '-',
#  'год',
#  'назад',
#  '. ',
#  'относительно',
#  'недорогой',
#  ', ',
#  'но',
#  'уж',
#  'точно',
#  'не',
#  'из',
#  'дешёвый',
#  ' — ',
#  'сервис',
#  'предполагать',
#  'себя',
#  '4',
#  'платный',
#  'линия',
#  'и',
#  'один',
#  'бесплатный',
#  '. ',
#  'даба',
#  'написать',
#  'этот',
#  'обзор',
#  'я',
#  'не',
#  'полениться',
#  'заплатить',
#  '19',
#  'доллар',
#  ' (',
#  'в',
#  'месяц',
#  ') ',
#  'выбрать',
#  'средний',
#  'вариант',
#  ' — ',
#  'для',
#  'несколько',
#  'проект',
#  'с',
#  'включить',
#  'дополнительный',
#  'функция',
#  '. ',
#  'да',
#  '-',
#  'да',
#  ', ',
#  'сервис',
#  'не',
#  'бесплатный',
#  '. ',
#  'точнее',
#  'бесплатный',
#  'возможность',
#  'потестировать',
#  'есть',
#  ', ',
#  'но',
#  'она',
#  'немного',
#  'обрезать',
#  ' (',
#  'можно',
#  'отслеживать',
#  'только',
#  '5000',
#  'посетитель',
#  'и',
#  'всего',
#  '4',
#  'страница',
#  'на',
#  'сайт',
#  ' (',
#  'внимание',
#  ' — ',
#  '4',
#  'страница',
#  ', ',
#  'а',
#  'не',
#  'сайт',
#  '), ',
#  'том',
#  '.',
#  'е',
#  '.',
#  'вполне',
#  'хватать',
#  'для',
#  'тот',
#  ', ',
#  'чтобы',
#  'понять',
#  'полезность',
#  'сервис',
#  ')',
#  '. ',
#  'зачем',
#  'это',
#  '? ',
#  'с',
#  'помощь',
#  'это',
#  'сервис',
#  'можно',
#  'тасовать',
#  'блок',
#  'на',
#  'сайт',
#  ', ',
#  'который',
#  'полезный',
#  'пользователь',
#  'большой',
#  'всего',
#  '. ',
#  'большой',
#  'не',
#  'нужно',
#  'спорить',
#  'создатель',
#  ' — ',
#  'какой',
#  'блок',
#  'где',
#  'расположить',
#  '. ',
#  'в',
#  'это',
#  'имя',
#  'помочь',
#  'сумасшедший',
#  'яйцо',
#  '. ',
#  'также',
#  'этот',
#  'сервис',
#  'помочь',
#  'вы',
#  'понять',
#  ' — ',
#  'в',
#  'какой',
#  'зона',
#  'сайт',
#  'хороший',
#  'всего',
#  'располагать',
#  'реклама',
#  ', ',
#  'когда',
#  'в',
#  'ваш',
#  'сервис',
#  'речь',
#  'зайти',
#  'о',
#  'монетизация',
#  '. ',
#  'ведь',
#  'альтруизм',
#  'это',
#  'хорошо',
#  ', ',
#  'а',
#  'деньга',
#  'на',
#  'содержание',
#  'сервис',
#  'нужный',
#  ', ',
#  'и',
#  'не',
#  'лишний',
#  'быть',
#  'вычислить',
#  'зона',
#  'где',
#  'реклама',
#  'быть',
#  'приносить',
#  'наибольший',
#  'отдача',
#  ', ',
#  'и',
#  'наименьший',
#  'раздражение',
#  'у',
#  'пользователь',
#  '. ',
#  'как',
#  'это',
#  'работать',
#  '? ',
#  'никакой',
#  'километровый',
#  'скрипт',
#  'вставлять',
#  'не',
#  'нужно',
#  ', ',
#  'достаточно',
#  'вставиь',
#  '2',
#  'строчка',
#  'яваскрипт',
#  ', ',
#  'и',
#  'сервис',
#  'начать',
#  'отслеживание',
#  '. ',
#  'насколько',
#  'я',
#  'понять',
#  ' — ',
#  'исполнительный',
#  'скрипт',
#  'работать',
#  'на',
#  'сервер',
#  'crazyegg',
#  ' , ',
#  'поэтому',
#  'ваш',
#  'сайт',
#  'от',
#  'это',
#  'в',
#  'производительность',
#  'не',
#  'потерять',
#  'ни',
#  'секунда',
#  ', ',
#  'а',
#  'полезность',
#  'довольно',
#  'таки',
#  'большой',
#  '. ',
#  'сколько',
#  'это',
#  'стоить',
#  '? ',
#  'как',
#  'я',
#  'уже',
#  'упоминать',
#  ' — ',
#  'сервис',
#  'далеко',
#  'не',
#  'бесплатный',
#  ', ',
#  'хоть',
#  'и',
#  'иметь',
#  'тестовый',
#  '-',
#  'бесплатный',
#  'версия',
#  '. ',
#  'рассказать',
#  'дробный',
#  'о',
#  'тарификация',
#  '. ',
#  '1',
#  '. ',
#  'бесплатный',
#  'тестовый',
#  'версия',
#  '. ',
#  'включать',
#  'в',
#  'себя',
#  'возможность',
#  'отслеживание',
#  '5',
#  '000',
#  'посещение',
#  ', ',
#  '4',
#  'страница',
#  'на',
#  'сайт',
#  '. ',
#  '2',
#  '. ',
#  'базовый',
#  'версия',
#  '. ',
#  'в',
#  'этот',
#  'версия',
#  'можно',
#  'отследить',
#  '10',
#  '000',
#  'посещение',
#  ', ',
#  'и',
#  '10',
#  'страница',
#  ', ',
#  'что',
#  'вполне',
#  'достаточно',
#  'для',
#  'среднее',
#  'корпоративный',
#  'сайт',
#  '. ',
#  'стоить',
#  'базовый',
#  'комплект',
#  ' — ',
#  '9',
#  'доллар',
#  'в',
#  'месяц',
#  '. ',
#  'в',
#  'этот',
#  'комплект',
#  'включить',
#  'весь',
#  'дополнительный',
#  'функция',
#  '. ',
#  '3',
#  '. ',
#  'версия',
#  ' «',
#  'стандарт',
#  '»',
#  '. ',
#  'в',
#  'она',
#  'входить',
#  'возможность',
#  'отслеживание',
#  '25',
#  '000',
#  'посещение',
#  'на',
#  '20',
#  'страница',
#  '. ',
#  'вполне',
#  'подходить',
#  'для',
#  'тестирование',
#  'новое',
#  'стартап',
#  '. ',
#  'стоить',
#  'она',
#  '19',
#  'доллар',
#  'в',
#  'месяц',
#  ', ',
#  'именно',
#  'её',
#  'я',
#  'купить',
#  'для',
#  'тестирование',
#  'сервис',
#  ', ',
#  'и',
#  'написание',
#  'это',
#  'обзор',
#  '. ',
#  '4',
#  '. ',
#  'версия',
#  ' «',
#  'плюс',
#  '»',
#  '. ',
#  'отличаться',
#  'от',
#  'предыдущий',
#  'возможность',
#  'отслеживание',
#  '100',
#  '000',
#  'посещение',
#  ', ',
#  '50',
#  'страница',
#  '. ',
#  'очень',
#  'хороший',
#  'тариф',
#  'для',
#  'крупный',
#  'сервис',
#  '. ',
#  'стоить',
#  '49',
#  'доллар',
#  'в',
#  'месяц',
#  '. ',
#  'довольно',
#  'большой',
#  'деньга',
#  'за',
#  'сервис',
#  ', ',
#  'но',
#  'они',
#  'обычно',
#  'с',
#  'лихва',
#  'окупаться',
#  '. ',
#  '5',
#  '. ',
#  'версия',
#  ' «',
#  'про',
#  '»',
#  '. ',
#  'стоить',
#  'почти',
#  '100',
#  'доллар',
#  ', ',
#  'иметь',
#  'возможность',
#  'отследить',
#  '250',
#  '000',
#  'посещение',
#  'на',
#  'сто',
#  'страница',
#  '. ',
#  'тариф',
#  'подходить',
#  'для',
#  'монстр',
#  'с',
#  'большой',
#  'посещаемость',
#  'и',
#  'больший',
#  'количество',
#  'страница',
#  '. ',
#  'есть',
#  'и',
#  'аналог',
#  'я',
#  'не',
#  'полениться',
#  ', ',
#  'и',
#  'собрать',
#  'ещё',
#  'пара',
#  'ссылка',
#  'с',
#  'аналог',
#  ', ',
#  'который',
#  'предлагать',
#  'такой',
#  'же',
#  'услуга',
#  ', ',
#  'но',
#  'немного',
#  'дешёвый',
#  '. ',
#  '1',
#  '. ',
#  'google',
#  'analytics',
#  ' — ',
#  'бесплатный',
#  'сервис',
#  'для',
#  'сбор',
#  'и',
#  'анализ',
#  'статистика',
#  ', ',
#  'вывод',
#  'статистика',
#  'в',
#  'наиболее',
#  'наглядный',
#  'форма',
#  ', ',
#  'и',
#  'без',
#  'разнообразный',
#  'рейтинг',
#  ', ',
#  'счётчик',
#  '. ',
#  'очень',
#  'подробный',
#  'и',
#  'полезный',
#  'вещь',
#  '. ',
#  'рекомендовать',
#  ', ',
#  'том',
#  '.',
#  'к',
#  '.',
#  'сам',
#  'пользоваться',
#  'имя',
#  'для',
#  'это',
#  'блог',
#  '. ',
#  '2',
#  '. ',
#  'mapsurface',
#  ' — ',
#  'сам',
#  'ещё',
#  'не',
#  'использовать',
#  ' (',
#  'том',
#  '.',
#  'к',
#  '.',
#  'предпочесть',
#  'crazyegg',
#  '), ',
#  'но',
#  'врядлить',
#  'быть',
#  'плохой',
#  'сервис',
#  'собрать',
#  'бы',
#  'множество',
#  'положительный',
#  'отзыв',
#  '. ',
#  'к',
#  'сожаление',
#  'он',
#  'сейчас',
#  'находиться',
#  'в',
#  'статус',
#  'закрытый',
#  'бета',
#  '. ',
#  'вывод',
#  'использовать',
#  'можно',
#  ', ',
#  'и',
#  'нужно',
#  '. ',
#  'вот',
#  'только',
#  'тариф',
#  'довольно',
#  'больно',
#  'кусаться',
#  ', ',
#  'но',
#  'обычно',
#  'этот',
#  'деньга',
#  'потом',
#  'с',
#  'лихва',
#  'отбиваться',
#  'на',
#  'повышение',
#  'конвертация',
#  'посетитель',
#  'в',
#  'деньга',
#  '. ',
#  'использовать',
#  'сервис',
#  'нужно',
#  'для',
#  'тестирование',
#  'рекламный',
#  'место',
#  'и',
#  'удобство',
#  'отдельный',
#  'страница',
#  ', ',
#  'что',
#  'помогать',
#  'опять',
#  'же',
#  'повысить',
#  'конвертация',
#  '. ',
#  'в',
#  'общий',
#  'и',
#  'целое',
#  ' — ',
#  'полезный',
#  'вещь',
#  'для',
#  'каждый',
#  'владелец',
#  'сайт',
#  ', ',
#  'а',
#  'для',
#  'юзабилистый',
#  'вообще',
#  'практически',
#  'обязательный',
#  '. ',
#  'к',
#  'счастие',
#  'для',
#  'человек',
#  ', ',
#  'который',
#  'поиздержаться',
#  'деньга',
#  'в',
#  'это',
#  'месяц',
#  ' — ',
#  'есть',
#  'полезный',
#  'аналог',
#  '. ',
#  'автор',
#  ': ',
#  'ярослав',
#  'бирзула',
#  ' (',
#  'dezmaster',
#  ')',
#  '. ',
#  'источник',
#  ': ',
#  'блог',
#  'о',
#  'юзабилить',
#  'веб',
#  'интерфейс',
#  '. ',
#  'ps',
#  ': ',
#  'весь',
#  'с',
#  'прошедшее',
#  'новый',
#  'год',
#  '! ',
#  'от',
#  'весь',
#  'душа',
#  'желать',
#  'вы',
#  'всего',
#  'самый',
#  '-',
#  'самый',
#  'хороший',
#  ', ',
#  'что',
#  'вы',
#  'желать',
#  'только',
#  'в',
#  'самый',
#  'сокровенный',
#  'мечта',
#  '. ',
#  'удачно',
#  'вы',
#  'провести',
#  'время',
#  '.',
#  '\n']

# %%
len(mystem_lemmas), len(pymorphy_lemmas)
# Out:
# (884, 884)

# %%
for x,y in zip(mystem_lemmas,pymorphy_lemmas):
    print(x, ' --- ',y)
# Out:
# сегодняшний  ---  сегодняшний
# заметка  ---  заметка
# быть  ---  быть
# о  ---  о
# сервис  ---  сервис
# отслеживание  ---  отслеживание
# активность  ---  активность
# пользователь  ---  пользователь
#  —   ---   —
# CrazyEgg  ---  crazyegg
# .   ---  .
# я  ---  я
# не  ---  не
# знать  ---  знать
# кто  ---  кома
# обязанный  ---  обязать
# сервис  ---  сервис
# такой  ---  такой
# говорящий  ---  говорящий
# имя  ---  имя
# ,   ---  ,
# но  ---  но
# оно  ---  оно
# работать  ---  работать
# ,   ---  ,
# и  ---  и
# хорошо  ---  хорошо
# .   ---  .
# запоминаться  ---  запоминаться
# ?   ---  ?
# отлично  ---  отлично
# !   ---  !
# что  ---  что
# это  ---  это
# такой  ---  такой
# ?   ---  ?
# как  ---  как
# уже  ---  уже
# сказать  ---  сказать
# выше  ---  выше
# это  ---  это
# сервис  ---  сервис
# для  ---  для
# отслеживание  ---  отслеживание
# перемещение  ---  перемещение
# пользователь  ---  пользователь
# по  ---  по
# сайт  ---  сайт
#  —   ---   —
# кто  ---  кто
# куда  ---  куда
# кликнуть  ---  кликнуть
# ,   ---  ,
# какой  ---  какой
# ссылка  ---  ссылка
# наиболее  ---  наиболее
# популярный  ---  популярный
# и  ---  и
# тот  ---  тот
# подобный  ---  подобный
# ,   ---  ,
# разнородный  ---  разнородный
# информация  ---  информация
# для  ---  для
# юзабилист  ---  юзабилист
# .   ---  .
# сервис  ---  сервис
# позволять  ---  позволять
# отслеживать  ---  отслеживать
# активность  ---  активность
# определенный  ---  определённый
# пользователь  ---  пользователь
# ,   ---  ,
# и  ---  и
# выводить  ---  выводить
# этот  ---  этот
# данные  ---  дать
# в  ---  в
# различный  ---  различный
# форма  ---  форма
# : «  ---  : «
# инфракрасный  ---  инфракрасный
# » —   ---  » —
# где  ---  где
# чем  ---  чем
# активно  ---  активный
# область  ---  область
# ,   ---  ,
# тем  ---  тем
# она  ---  она
#  «  ---   «
# тепло  ---  тёплый
# »,   ---  »,
# салют  ---  салют
#  (  ---   (
# чем  ---  чем
# активно  ---  активный
# область  ---  область
# ,   ---  ,
# тем  ---  тем
# много  ---  большой
# конфеть  ---  конфести
# ),   ---  ),
# простой  ---  простой
# список  ---  список
# с  ---  с
# сортировка  ---  сортировка
# по  ---  по
# активность  ---  активность
# ,   ---  ,
# колба  ---  колба
#  (  ---   (
# чем  ---  чем
# заполненный  ---  залненный
# колба  ---  колба
# ,   ---  ,
# тем  ---  тем
# активно  ---  активный
# область  ---  область
# ),   ---  ),
# облако  ---  облако
#  (  ---   (
# на  ---  на
# мой  ---  мой
# взгляд  ---  взгляд
# наиболее  ---  наиболее
# удобный  ---  удобный
# вариант  ---  вариант
#  —   ---   —
# совмещать  ---  совмещать
# в  ---  в
# себя  ---  себя
# весь  ---  весь
# остальной  ---  остальной
# вместе  ---  вместе
# взять  ---  взять
# )  ---  )
# .   ---  .
# для  ---  для
# кто  ---  кто
# это  ---  это
# ?   ---  ?
# разумеется  ---  разумеется
# сервис  ---  сервис
# изначально  ---  изначально
# планироваться  ---  планироваться
# как  ---  как
# первый  ---  один
# помощник  ---  помощник
# для  ---  для
# юзабилист  ---  юзабилист
# ,   ---  ,
# но  ---  но
# пользоваться  ---  пользоваться
# они  ---  имя
# может  ---  мочь
# каждый  ---  каждый
# ,   ---  ,
# у  ---  у
# кто  ---  кто
# быть  ---  есть
# деньги  ---  деньга
#  —   ---   —
# интуитивный  ---  интуитивный
# интерфейс  ---  интерфейс
# ,   ---  ,
# и  ---  и
# хороший  ---  хороший
# дизайн  ---  дизайн
# давать  ---  давать
# о  ---  о
# себя  ---  себя
# знать  ---  знать
#  —   ---   —
# сервис  ---  сервис
# массово  ---  массово
# популяризироваться  ---  популяризироваться
# пол  ---  половина
# год  ---  год
# -  ---  -
# год  ---  год
# назад  ---  назад
# .   ---  .
# относительно  ---  относительно
# недорогой  ---  недорогой
# ,   ---  ,
# но  ---  но
# уж  ---  уж
# точно  ---  точно
# не  ---  не
# из  ---  из
# дешевый  ---  дешёвый
#  —   ---   —
# сервис  ---  сервис
# предполагать  ---  предполагать
# себя  ---  себя
# 4  ---  4
# платный  ---  платный
# линия  ---  линия
# и  ---  и
# один  ---  один
# бесплатный  ---  бесплатный
# .   ---  .
# дабы  ---  даба
# написать  ---  написать
# этот  ---  этот
# обзор  ---  обзор
# я  ---  я
# не  ---  не
# полениться  ---  полениться
# заплатить  ---  заплатить
# 19  ---  19
# доллар  ---  доллар
#  (  ---   (
# в  ---  в
# месяц  ---  месяц
# )   ---  )
# выбирать  ---  выбрать
# средний  ---  средний
# вариант  ---  вариант
#  —   ---   —
# для  ---  для
# несколько  ---  несколько
# проект  ---  проект
# с  ---  с
# включать  ---  включить
# дополнительный  ---  дополнительный
# функция  ---  функция
# .   ---  .
# да  ---  да
# -  ---  -
# да  ---  да
# ,   ---  ,
# сервис  ---  сервис
# не  ---  не
# бесплатный  ---  бесплатный
# .   ---  .
# точно  ---  точнее
# бесплатный  ---  бесплатный
# возможность  ---  возможность
# потестировать  ---  потестировать
# есть  ---  есть
# ,   ---  ,
# но  ---  но
# она  ---  она
# немного  ---  немного
# обрезать  ---  обрезать
#  (  ---   (
# можно  ---  можно
# отслеживать  ---  отслеживать
# только  ---  только
# 5000  ---  5000
# посетитель  ---  посетитель
# и  ---  и
# все  ---  всего
# 4  ---  4
# страница  ---  страница
# на  ---  на
# сайт  ---  сайт
#  (  ---   (
# внимание  ---  внимание
#  —   ---   —
# 4  ---  4
# страница  ---  страница
# ,   ---  ,
# а  ---  а
# не  ---  не
# сайт  ---  сайт
# ),   ---  ),
# т  ---  том
# .  ---  .
# е  ---  е
# .  ---  .
# вполне  ---  вполне
# хватать  ---  хватать
# для  ---  для
# то  ---  тот
# ,   ---  ,
# чтобы  ---  чтобы
# понимать  ---  понять
# полезность  ---  полезность
# сервис  ---  сервис
# )  ---  )
# .   ---  .
# зачем  ---  зачем
# это  ---  это
# ?   ---  ?
# с  ---  с
# помощь  ---  помощь
# этот  ---  это
# сервис  ---  сервис
# можно  ---  можно
# тасовать  ---  тасовать
# блок  ---  блок
# на  ---  на
# сайт  ---  сайт
# ,   ---  ,
# который  ---  который
# полезный  ---  полезный
# пользователь  ---  пользователь
# много  ---  большой
# все  ---  всего
# .   ---  .
# больше  ---  большой
# не  ---  не
# нужно  ---  нужно
# спорить  ---  спорить
# создатель  ---  создатель
#  —   ---   —
# какой  ---  какой
# блок  ---  блок
# где  ---  где
# располагать  ---  расположить
# .   ---  .
# в  ---  в
# это  ---  это
# он  ---  имя
# помогать  ---  помочь
# сумасшедший  ---  сумасшедший
# яйцо  ---  яйцо
# .   ---  .
# также  ---  также
# этот  ---  этот
# сервис  ---  сервис
# помогать  ---  помочь
# вы  ---  вы
# понимать  ---  понять
#  —   ---   —
# в  ---  в
# какой  ---  какой
# зона  ---  зона
# сайт  ---  сайт
# хорошо  ---  хороший
# все  ---  всего
# располагать  ---  располагать
# реклама  ---  реклама
# ,   ---  ,
# когда  ---  когда
# в  ---  в
# ваш  ---  ваш
# сервис  ---  сервис
# речь  ---  речь
# зайти  ---  зайти
# о  ---  о
# монетизация  ---  монетизация
# .   ---  .
# ведь  ---  ведь
# альтруизм  ---  альтруизм
# это  ---  это
# хорошо  ---  хорошо
# ,   ---  ,
# а  ---  а
# деньги  ---  деньга
# на  ---  на
# содержание  ---  содержание
# сервис  ---  сервис
# нужный  ---  нужный
# ,   ---  ,
# и  ---  и
# не  ---  не
# лишний  ---  лишний
# быть  ---  быть
# вычислять  ---  вычислить
# зона  ---  зона
# где  ---  где
# реклама  ---  реклама
# быть  ---  быть
# приносить  ---  приносить
# большой  ---  наибольший
# отдача  ---  отдача
# ,   ---  ,
# и  ---  и
# маленький  ---  наименьший
# раздражение  ---  раздражение
# у  ---  у
# пользователь  ---  пользователь
# .   ---  .
# как  ---  как
# это  ---  это
# работать  ---  работать
# ?   ---  ?
# никакой  ---  никакой
# километровый  ---  километровый
# скрипт  ---  скрипт
# вставлять  ---  вставлять
# не  ---  не
# нужно  ---  нужно
# ,   ---  ,
# достаточно  ---  достаточно
# вставиь  ---  вставиь
# 2  ---  2
# строчка  ---  строчка
# яваскрипт  ---  яваскрипт
# ,   ---  ,
# и  ---  и
# сервис  ---  сервис
# начинать  ---  начать
# отслеживание  ---  отслеживание
# .   ---  .
# насколько  ---  насколько
# я  ---  я
# понимать  ---  понять
#  —   ---   —
# исполнительный  ---  исполнительный
# скрипт  ---  скрипт
# работать  ---  работать
# на  ---  на
# сервер  ---  сервер
# CrazyEgg  ---  crazyegg
#  ,   ---   ,
# поэтому  ---  поэтому
# ваш  ---  ваш
# сайт  ---  сайт
# от  ---  от
# это  ---  это
# в  ---  в
# производительность  ---  производительность
# не  ---  не
# потерять  ---  потерять
# ни  ---  ни
# секунда  ---  секунда
# ,   ---  ,
# а  ---  а
# полезность  ---  полезность
# довольно  ---  довольно
# таки  ---  таки
# большой  ---  большой
# .   ---  .
# сколько  ---  сколько
# это  ---  это
# стоять  ---  стоить
# ?   ---  ?
# как  ---  как
# я  ---  я
# уже  ---  уже
# упоминать  ---  упоминать
#  —   ---   —
# сервис  ---  сервис
# далеко  ---  далеко
# не  ---  не
# бесплатный  ---  бесплатный
# ,   ---  ,
# хоть  ---  хоть
# и  ---  и
# иметь  ---  иметь
# тестовый  ---  тестовый
# -  ---  -
# бесплатный  ---  бесплатный
# версия  ---  версия
# .   ---  .
# рассказывать  ---  рассказать
# подробно  ---  дробный
# о  ---  о
# тарификация  ---  тарификация
# .   ---  .
# 1  ---  1
# .   ---  .
# бесплатный  ---  бесплатный
# тестовый  ---  тестовый
# версия  ---  версия
# .   ---  .
# включать  ---  включать
# в  ---  в
# себя  ---  себя
# возможность  ---  возможность
# отслеживание  ---  отслеживание
# 5  ---  5
# 000  ---  000
# посещение  ---  посещение
# ,   ---  ,
# 4  ---  4
# страница  ---  страница
# на  ---  на
# сайт  ---  сайт
# .   ---  .
# 2  ---  2
# .   ---  .
# базовый  ---  базовый
# версия  ---  версия
# .   ---  .
# в  ---  в
# этот  ---  этот
# версия  ---  версия
# можно  ---  можно
# отслеживать  ---  отследить
# 10  ---  10
# 000  ---  000
# посещение  ---  посещение
# ,   ---  ,
# и  ---  и
# 10  ---  10
# страница  ---  страница
# ,   ---  ,
# что  ---  что
# вполне  ---  вполне
# достаточно  ---  достаточно
# для  ---  для
# средний  ---  среднее
# корпоративный  ---  корпоративный
# сайт  ---  сайт
# .   ---  .
# стоять  ---  стоить
# базовый  ---  базовый
# комплект  ---  комплект
#  —   ---   —
# 9  ---  9
# доллар  ---  доллар
# в  ---  в
# месяц  ---  месяц
# .   ---  .
# в  ---  в
# этот  ---  этот
# комплект  ---  комплект
# включать  ---  включить
# весь  ---  весь
# дополнительный  ---  дополнительный
# функция  ---  функция
# .   ---  .
# 3  ---  3
# .   ---  .
# версия  ---  версия
#  «  ---   «
# стандарт  ---  стандарт
# »  ---  »
# .   ---  .
# в  ---  в
# она  ---  она
# входить  ---  входить
# возможность  ---  возможность
# отслеживание  ---  отслеживание
# 25  ---  25
# 000  ---  000
# посещение  ---  посещение
# на  ---  на
# 20  ---  20
# страница  ---  страница
# .   ---  .
# вполне  ---  вполне
# подходить  ---  подходить
# для  ---  для
# тестирование  ---  тестирование
# новый  ---  новое
# стартап  ---  стартап
# .   ---  .
# стоить  ---  стоить
# она  ---  она
# 19  ---  19
# доллар  ---  доллар
# в  ---  в
# месяц  ---  месяц
# ,   ---  ,
# именно  ---  именно
# она  ---  её
# я  ---  я
# купить  ---  купить
# для  ---  для
# тестирование  ---  тестирование
# сервис  ---  сервис
# ,   ---  ,
# и  ---  и
# написание  ---  написание
# этот  ---  это
# обзор  ---  обзор
# .   ---  .
# 4  ---  4
# .   ---  .
# версия  ---  версия
#  «  ---   «
# плюс  ---  плюс
# »  ---  »
# .   ---  .
# отличаться  ---  отличаться
# от  ---  от
# предыдущий  ---  предыдущий
# возможность  ---  возможность
# отслеживание  ---  отслеживание
# 100  ---  100
# 000  ---  000
# посещение  ---  посещение
# ,   ---  ,
# 50  ---  50
# страница  ---  страница
# .   ---  .
# очень  ---  очень
# хороший  ---  хороший
# тариф  ---  тариф
# для  ---  для
# крупный  ---  крупный
# сервис  ---  сервис
# .   ---  .
# стоять  ---  стоить
# 49  ---  49
# доллар  ---  доллар
# в  ---  в
# месяц  ---  месяц
# .   ---  .
# довольно  ---  довольно
# большой  ---  большой
# деньги  ---  деньга
# за  ---  за
# сервис  ---  сервис
# ,   ---  ,
# но  ---  но
# они  ---  они
# обычно  ---  обычно
# с  ---  с
# лихва  ---  лихва
# окупаться  ---  окупаться
# .   ---  .
# 5  ---  5
# .   ---  .
# версия  ---  версия
#  «  ---   «
# про  ---  про
# »  ---  »
# .   ---  .
# стоять  ---  стоить
# почти  ---  почти
# 100  ---  100
# доллар  ---  доллар
# ,   ---  ,
# иметь  ---  иметь
# возможность  ---  возможность
# отслеживать  ---  отследить
# 250  ---  250
# 000  ---  000
# посещение  ---  посещение
# на  ---  на
# сто  ---  сто
# страница  ---  страница
# .   ---  .
# тариф  ---  тариф
# подходить  ---  подходить
# для  ---  для
# монстр  ---  монстр
# с  ---  с
# большой  ---  большой
# посещаемость  ---  посещаемость
# и  ---  и
# большой  ---  больший
# количество  ---  количество
# страница  ---  страница
# .   ---  .
# быть  ---  есть
# и  ---  и
# аналог  ---  аналог
# я  ---  я
# не  ---  не
# полениться  ---  полениться
# ,   ---  ,
# и  ---  и
# собирать  ---  собрать
# еще  ---  ещё
# пара  ---  пара
# ссылка  ---  ссылка
# с  ---  с
# аналог  ---  аналог
# ,   ---  ,
# который  ---  который
# предлагать  ---  предлагать
# такой  ---  такой
# же  ---  же
# услуга  ---  услуга
# ,   ---  ,
# но  ---  но
# немного  ---  немного
# дешево  ---  дешёвый
# .   ---  .
# 1  ---  1
# .   ---  .
# Google  ---  google
# Analytics  ---  analytics
#  —   ---   —
# бесплатный  ---  бесплатный
# сервис  ---  сервис
# для  ---  для
# сбор  ---  сбор
# и  ---  и
# анализ  ---  анализ
# статистика  ---  статистика
# ,   ---  ,
# вывод  ---  вывод
# статистика  ---  статистика
# в  ---  в
# наиболее  ---  наиболее
# наглядный  ---  наглядный
# форма  ---  форма
# ,   ---  ,
# и  ---  и
# без  ---  без
# разнообразный  ---  разнообразный
# рейтинг  ---  рейтинг
# ,   ---  ,
# счетчик  ---  счётчик
# .   ---  .
# очень  ---  очень
# подробный  ---  подробный
# и  ---  и
# полезный  ---  полезный
# вещь  ---  вещь
# .   ---  .
# рекомендовать  ---  рекомендовать
# ,   ---  ,
# т  ---  том
# .  ---  .
# к  ---  к
# .  ---  .
# сам  ---  сам
# пользоваться  ---  пользоваться
# он  ---  имя
# для  ---  для
# этот  ---  это
# блог  ---  блог
# .   ---  .
# 2  ---  2
# .   ---  .
# MapSurface  ---  mapsurface
#  —   ---   —
# сам  ---  сам
# еще  ---  ещё
# не  ---  не
# использовать  ---  использовать
#  (  ---   (
# т  ---  том
# .  ---  .
# к  ---  к
# .  ---  .
# предпочитать  ---  предпочесть
# CrazyEgg  ---  crazyegg
# ),   ---  ),
# но  ---  но
# врядли  ---  врядлить
# быть  ---  быть
# плохой  ---  плохой
# сервис  ---  сервис
# собирать  ---  собрать
# бы  ---  бы
# множество  ---  множество
# положительный  ---  положительный
# отзыв  ---  отзыв
# .   ---  .
# к  ---  к
# сожаление  ---  сожаление
# он  ---  он
# сейчас  ---  сейчас
# находиться  ---  находиться
# в  ---  в
# статус  ---  статус
# закрытый  ---  закрытый
# бета  ---  бета
# .   ---  .
# вывод  ---  вывод
# использовать  ---  использовать
# можно  ---  можно
# ,   ---  ,
# и  ---  и
# нужно  ---  нужно
# .   ---  .
# вот  ---  вот
# только  ---  только
# тариф  ---  тариф
# довольно  ---  довольно
# больно  ---  больно
# кусаться  ---  кусаться
# ,   ---  ,
# но  ---  но
# обычно  ---  обычно
# этот  ---  этот
# деньги  ---  деньга
# потом  ---  потом
# с  ---  с
# лихва  ---  лихва
# отбиваться  ---  отбиваться
# на  ---  на
# повышение  ---  повышение
# конвертация  ---  конвертация
# посетитель  ---  посетитель
# в  ---  в
# деньги  ---  деньга
# .   ---  .
# использовать  ---  использовать
# сервис  ---  сервис
# нужный  ---  нужно
# для  ---  для
# тестирование  ---  тестирование
# рекламный  ---  рекламный
# место  ---  место
# и  ---  и
# удобство  ---  удобство
# отдельный  ---  отдельный
# страница  ---  страница
# ,   ---  ,
# что  ---  что
# помогать  ---  помогать
# опять  ---  опять
# же  ---  же
# повышать  ---  повысить
# конвертация  ---  конвертация
# .   ---  .
# в  ---  в
# общий  ---  общий
# и  ---  и
# целое  ---  целое
#  —   ---   —
# полезный  ---  полезный
# вещь  ---  вещь
# для  ---  для
# каждый  ---  каждый
# владелец  ---  владелец
# сайт  ---  сайт
# ,   ---  ,
# а  ---  а
# для  ---  для
# юзабилист  ---  юзабилистый
# вообще  ---  вообще
# практически  ---  практически
# обязательный  ---  обязательный
# .   ---  .
# к  ---  к
# счастие  ---  счастие
# для  ---  для
# человек  ---  человек
# ,   ---  ,
# который  ---  который
# поиздержаться  ---  поиздержаться
# деньги  ---  деньга
# в  ---  в
# этот  ---  это
# месяц  ---  месяц
#  —   ---   —
# быть  ---  есть
# полезный  ---  полезный
# аналог  ---  аналог
# .   ---  .
# автор  ---  автор
# :   ---  :
# ярослав  ---  ярослав
# бирзула  ---  бирзула
#  (  ---   (
# DezmASter  ---  dezmaster
# )  ---  )
# .   ---  .
# источник  ---  источник
# :   ---  :
# блог  ---  блог
# о  ---  о
# юзабилити  ---  юзабилить
# веб  ---  веб
# интерфейс  ---  интерфейс
# .   ---  .
# PS  ---  ps
# :   ---  :
# весь  ---  весь
# с  ---  с
# прошедший  ---  прошедшее
# новый  ---  новый
# год  ---  год
# !   ---  !
# от  ---  от
# весь  ---  весь
# душа  ---  душа
# желать  ---  желать
# вы  ---  вы
# весь  ---  всего
# самый  ---  самый
# -  ---  -
# самый  ---  самый
# хороший  ---  хороший
# ,   ---  ,
# что  ---  что
# вы  ---  вы
# желать  ---  желать
# только  ---  только
# в  ---  в
# самый  ---  самый
# сокровенный  ---  сокровенный
# мечта  ---  мечта
# .   ---  .
# удачно  ---  удачно
# вы  ---  вы
# проводить  ---  провести
# время  ---  время
# .  ---  .
#
#   ---

# %%
for x,y in zip(mystem_lemmas,pymorphy_lemmas):
    if x != y:
        print(x, ' --- ',y)
# Out:
# CrazyEgg  ---  crazyegg
# кто  ---  кома
# обязанный  ---  обязать
# определенный  ---  определённый
# данные  ---  дать
# активно  ---  активный
# тепло  ---  тёплый
# активно  ---  активный
# много  ---  большой
# конфеть  ---  конфести
# заполненный  ---  залненный
# активно  ---  активный
# первый  ---  один
# они  ---  имя
# может  ---  мочь
# быть  ---  есть
# деньги  ---  деньга
# пол  ---  половина
# дешевый  ---  дешёвый
# дабы  ---  даба
# выбирать  ---  выбрать
# включать  ---  включить
# точно  ---  точнее
# все  ---  всего
# т  ---  том
# то  ---  тот
# понимать  ---  понять
# этот  ---  это
# много  ---  большой
# все  ---  всего
# больше  ---  большой
# располагать  ---  расположить
# он  ---  имя
# помогать  ---  помочь
# помогать  ---  помочь
# понимать  ---  понять
# хорошо  ---  хороший
# все  ---  всего
# деньги  ---  деньга
# вычислять  ---  вычислить
# большой  ---  наибольший
# маленький  ---  наименьший
# начинать  ---  начать
# понимать  ---  понять
# CrazyEgg  ---  crazyegg
# стоять  ---  стоить
# рассказывать  ---  рассказать
# подробно  ---  дробный
# отслеживать  ---  отследить
# средний  ---  среднее
# стоять  ---  стоить
# включать  ---  включить
# новый  ---  новое
# она  ---  её
# этот  ---  это
# стоять  ---  стоить
# деньги  ---  деньга
# стоять  ---  стоить
# отслеживать  ---  отследить
# большой  ---  больший
# быть  ---  есть
# собирать  ---  собрать
# еще  ---  ещё
# дешево  ---  дешёвый
# Google  ---  google
# Analytics  ---  analytics
# счетчик  ---  счётчик
# т  ---  том
# он  ---  имя
# этот  ---  это
# MapSurface  ---  mapsurface
# еще  ---  ещё
# т  ---  том
# предпочитать  ---  предпочесть
# CrazyEgg  ---  crazyegg
# врядли  ---  врядлить
# собирать  ---  собрать
# деньги  ---  деньга
# деньги  ---  деньга
# нужный  ---  нужно
# повышать  ---  повысить
# юзабилист  ---  юзабилистый
# деньги  ---  деньга
# этот  ---  это
# быть  ---  есть
# DezmASter  ---  dezmaster
# юзабилити  ---  юзабилить
# PS  ---  ps
# прошедший  ---  прошедшее
# весь  ---  всего
# проводить  ---  провести

# %% [markdown]
# Майстем не приводит леммы к нижнему регистру, в отличии от пайморфи

# %% [markdown]
# ## 5. Разбиение на предложения в Mystem (2 балла)
#
# С помощью Mystem разделите текст из первого задания (очищенный) на предложения. Сравните разбиение с razdel.sentenize

# %%
from razdel import sentenize
sents = list(sentenize(text))
sents_razdel = [sent.text for sent in sents]
sents_razdel
# Out:
# ['Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg .',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.',
#  'Запоминается?',
#  'Отлично!',
#  'Что это такое?',
#  'Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.',
#  'Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).',
#  'Для кого это?',
#  'Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад.',
#  'Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную.',
#  'Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.',
#  'Да-да, сервис не бесплатен.',
#  'Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).',
#  'Зачем это?',
#  'С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего.',
#  'Больше не нужно спорить создателям — какой блок где расположить.',
#  'В этом им поможет Сумасшедшее яйцо .',
#  'Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации.',
#  'Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.',
#  'Как это работает?',
#  'Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание.',
#  'Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg , поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.',
#  'Сколько это стоит?',
#  'Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию.',
#  'Расскажу подробнее о тарификации.',
#  '1. Бесплатная тестовая версия.',
#  'Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.',
#  '2. Базовая версия.',
#  'В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта.',
#  'Стоит базовый комплект — 9 долларов в месяц.',
#  'В этот комплект включены все дополнительные функции.',
#  '3. Версия «Стандарт».',
#  'В неё входит возможность отслеживания 25 000 посещений на 20 страницах.',
#  'Вполне подходит для тестирования нового стартапа.',
#  'Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.',
#  '4. Версия «Плюс».',
#  'Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц.',
#  'Очень хороший тариф для крупных сервисов.',
#  'Стоит 49 долларов в месяц.',
#  'Довольно большие деньги за сервис, но они обычно с лихвой окупаются.',
#  '5. Версия «Про».',
#  'Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах.',
#  'Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.',
#  'Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.',
#  '1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков.',
#  'Очень подробная и полезная вещь.',
#  'Рекомендую, т.к. сам пользуюсь им для этого блога.',
#  '2. MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов.',
#  'К сожалению он сейчас находится в статусе закрытой беты.',
#  'Вывод Использовать можно, и нужно.',
#  'Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги.',
#  'Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию.',
#  'В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна.',
#  'К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.',
#  'Автор: Ярослав Бирзул (DezmASter).',
#  'Источник: Блог о юзабилити веб интерфейсов .',
#  'PS: Всех с прошедшим Новым годом!',
#  'От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах.',
#  'Удачно вам провести время.']

# %%
f = open('text.txt', 'w', encoding='utf-8')
f.write(text)
f.close()

# %%
# !mystem -isc --format json text.txt text_parsed.txt

# %%
import json
t = [json.loads(line) for line in open('text_parsed.txt', encoding='utf-8')]

# %%
sents_mystem = []
str_sent = ''
for word in t[0]:
    if word['text'] != '\s':
        str_sent += word['text']
    else:
        sents_mystem.append(str_sent)
        str_sent = ''
sents_mystem
# Out:
# ['Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg . ',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. ',
#  'Запоминается? ',
#  'Отлично! ',
#  'Что это такое? ',
#  'Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов. ',
#  'Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые). ',
#  'Для кого это? ',
#  'Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. ',
#  'Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. ',
#  'Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями. ',
#  'Да-да, сервис не бесплатен. ',
#  'Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса). ',
#  'Зачем это? ',
#  'С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. ',
#  'Больше не нужно спорить создателям — какой блок где расположить. ',
#  'В этом им поможет Сумасшедшее яйцо . ',
#  'Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. ',
#  'Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей. ',
#  'Как это работает? ',
#  'Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. ',
#  'Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg , поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая. ',
#  'Сколько это стоит? ',
#  'Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. ',
#  'Расскажу подробнее о тарификации. 1. ',
#  'Бесплатная тестовая версия. ',
#  'Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте. 2. ',
#  'Базовая версия. ',
#  'В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. ',
#  'Стоит базовый комплект — 9 долларов в месяц. ',
#  'В этот комплект включены все дополнительные функции. 3. ',
#  'Версия «Стандарт». ',
#  'В неё входит возможность отслеживания 25 000 посещений на 20 страницах. ',
#  'Вполне подходит для тестирования нового стартапа. ',
#  'Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора. 4. ',
#  'Версия «Плюс». ',
#  'Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. ',
#  'Очень хороший тариф для крупных сервисов. ',
#  'Стоит 49 долларов в месяц. ',
#  'Довольно большие деньги за сервис, но они обычно с лихвой окупаются. 5. ',
#  'Версия «Про». ',
#  'Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. ',
#  'Тариф подходит для монстров с большой посещаемостью и большим количеством страниц. ',
#  'Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1. ',
#  'Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. ',
#  'Очень подробная и полезная вещь. ',
#  'Рекомендую, т.к. сам пользуюсь им для этого блога. 2. ',
#  'MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов. ',
#  'К сожалению он сейчас находится в статусе закрытой беты. ',
#  'Вывод Использовать можно, и нужно. ',
#  'Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги. ',
#  'Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию. ',
#  'В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна. ',
#  'К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги. ',
#  'Автор: Ярослав Бирзул (DezmASter). ',
#  'Источник: Блог о юзабилити веб интерфейсов . ',
#  'PS: Всех с прошедшим Новым годом! ',
#  'От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах. ']

# %%
len(sents_razdel), len(sents_mystem)
# Out:
# (59, 58)

# %%
for x,y in zip(sents_razdel, sents_mystem):
    print(x,' --- ',y,'\n')
# Out:
# Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg .  ---  Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg .
#
# Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.  ---  Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.
#
# Запоминается?  ---  Запоминается?
#
# Отлично!  ---  Отлично!
#
# Что это такое?  ---  Что это такое?
#
# Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.  ---  Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.
#
# Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).  ---  Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).
#
# Для кого это?  ---  Для кого это?
#
# Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад.  ---  Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад.
#
# Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную.  ---  Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную.
#
# Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.  ---  Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.
#
# Да-да, сервис не бесплатен.  ---  Да-да, сервис не бесплатен.
#
# Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).  ---  Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).
#
# Зачем это?  ---  Зачем это?
#
# С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего.  ---  С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего.
#
# Больше не нужно спорить создателям — какой блок где расположить.  ---  Больше не нужно спорить создателям — какой блок где расположить.
#
# В этом им поможет Сумасшедшее яйцо .  ---  В этом им поможет Сумасшедшее яйцо .
#
# Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации.  ---  Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации.
#
# Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.  ---  Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.
#
# Как это работает?  ---  Как это работает?
#
# Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание.  ---  Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание.
#
# Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg , поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.  ---  Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg , поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.
#
# Сколько это стоит?  ---  Сколько это стоит?
#
# Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию.  ---  Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию.
#
# Расскажу подробнее о тарификации.  ---  Расскажу подробнее о тарификации. 1.
#
# 1. Бесплатная тестовая версия.  ---  Бесплатная тестовая версия.
#
# Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.  ---  Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте. 2.
#
# 2. Базовая версия.  ---  Базовая версия.
#
# В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта.  ---  В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта.
#
# Стоит базовый комплект — 9 долларов в месяц.  ---  Стоит базовый комплект — 9 долларов в месяц.
#
# В этот комплект включены все дополнительные функции.  ---  В этот комплект включены все дополнительные функции. 3.
#
# 3. Версия «Стандарт».  ---  Версия «Стандарт».
#
# В неё входит возможность отслеживания 25 000 посещений на 20 страницах.  ---  В неё входит возможность отслеживания 25 000 посещений на 20 страницах.
#
# Вполне подходит для тестирования нового стартапа.  ---  Вполне подходит для тестирования нового стартапа.
#
# Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.  ---  Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора. 4.
#
# 4. Версия «Плюс».  ---  Версия «Плюс».
#
# Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц.  ---  Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц.
#
# Очень хороший тариф для крупных сервисов.  ---  Очень хороший тариф для крупных сервисов.
#
# Стоит 49 долларов в месяц.  ---  Стоит 49 долларов в месяц.
#
# Довольно большие деньги за сервис, но они обычно с лихвой окупаются.  ---  Довольно большие деньги за сервис, но они обычно с лихвой окупаются. 5.
#
# 5. Версия «Про».  ---  Версия «Про».
#
# Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах.  ---  Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах.
#
# Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.  ---  Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.
#
# Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.  ---  Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1.
#
# 1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков.  ---  Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков.
#
# Очень подробная и полезная вещь.  ---  Очень подробная и полезная вещь.
#
# Рекомендую, т.к. сам пользуюсь им для этого блога.  ---  Рекомендую, т.к. сам пользуюсь им для этого блога. 2.
#
# 2. MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов.  ---  MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов.
#
# К сожалению он сейчас находится в статусе закрытой беты.  ---  К сожалению он сейчас находится в статусе закрытой беты.
#
# Вывод Использовать можно, и нужно.  ---  Вывод Использовать можно, и нужно.
#
# Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги.  ---  Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги.
#
# Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию.  ---  Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию.
#
# В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна.  ---  В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна.
#
# К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.  ---  К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.
#
# Автор: Ярослав Бирзул (DezmASter).  ---  Автор: Ярослав Бирзул (DezmASter).
#
# Источник: Блог о юзабилити веб интерфейсов .  ---  Источник: Блог о юзабилити веб интерфейсов .
#
# PS: Всех с прошедшим Новым годом!  ---  PS: Всех с прошедшим Новым годом!
#
# От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах.  ---  От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах.

# %% [markdown]
# ## 6*. Дизамбигуация в Mystem (2 балла)

# %% [markdown]
# *необязательное задание на 10 баллов

# %% [markdown]
# Одна из фичей майстема - контекстная дизамбигуация (т.е. определение правильного разбора в зависимости от контекста).

# %% [markdown]
# Запустите mystem на очищенном тексте с дизамбигуацией и без и проверьте есть ли какие-то различия.

# %%
# ваш код
